# %% [markdown]
# # Adquisicion de Data

# %%
import pandas as pd

df_movies = pd.read_csv(r'.\Data\rotten_tomatoes_movies.csv')
df_reviews = pd.read_csv(r'.\Data\rotten_tomatoes_critic_reviews.csv')

# %% [markdown]
# # Preprocesamiento

# %%
df_movies.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
df_reviews.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# ...

# %% [markdown]
# Creamos el corpus con las columnas que creemos que son necesarias

# %%
#merged_data = pd.merge(df_movies,df_reviews, on='rotten_tomatoes_link', how='inner')
df_corpus = pd.merge( df_movies[[ 'rotten_tomatoes_link','movie_title']],df_reviews[['rotten_tomatoes_link','review_content']],  on='rotten_tomatoes_link')

# %% [markdown]
# ### Convertir a minusculas y eliminar caracteres especiales

# %%
import pandas as pd
import re

def limpiarTexto(texto):
    # Convertir a minúsculas
    texto = texto.lower()
    # Eliminar caracteres especiales (excepto espacios y letras)
    texto = re.sub(r'[^a-zA-Z\s]', '', texto)
    return texto

# %%
df_corpus['textoLimpio'] = df_corpus['review_content'].apply(limpiarTexto)
df_corpus
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df_corpus['textoLimpio'] = df_corpus['review_content'].apply(limpiarTexto)
#       2 df_corpus
#
# File c:\Users\dicam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
# El error de anterior nos indica que en la columna review se encuentran datos Nan que nos impide procesar los textos
# Los eliminamos con dropna
df_corpus.dropna(subset=['review_content'], inplace=True)
df_corpus.head()
# Out:
#   rotten_tomatoes_link                                        movie_title  \
# 0            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 1            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 2            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 3            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 4            m/0814255  Percy Jackson & the Olympians: The Lightning T...
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...

# %%
# Procedemos a limpiar el texto y creamos una columna en el dataframe corpus
df_corpus['textoLimpio'] = df_corpus['review_content'].apply(limpiarTexto)
df_corpus.head()
# Out:
#   rotten_tomatoes_link                                        movie_title  \
# 0            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 1            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 2            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 3            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 4            m/0814255  Percy Jackson & the Olympians: The Lightning T...
#
#                                       review_content  \
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...
#
#                                          textoLimpio
# 0  a fantasy adventure that fuses greek mythology...
# 1  uma thurman as medusa the gorgon with a coiffu...
# ...

# %% [markdown]
# ### Eliminación de stopwords y tokenizacion

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk

# Descargar stopwords de NLTK
nltk.download('stopwords')

# Función para eliminar stopwords
def eliminarStopwords(texto):
    palabras = texto.split()  # Divide el texto en palabras
    stop_words = set(stopwords.words('english'))  # Obtén las stopwords en inglés
    palabras_filtradas = [palabra for palabra in palabras if palabra.lower() not in stop_words]  # Filtra las stopwords
    return palabras_filtradas  #Recosntruye el texto sin las stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dicam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_corpus['textoSinStopWordsTokenizado'] = df_corpus['textoLimpio'].apply(eliminarStopwords)

# %%
df_corpus.head()
# Out:
#   rotten_tomatoes_link                                        movie_title  \
# 0            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 1            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 2            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 3            m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 4            m/0814255  Percy Jackson & the Olympians: The Lightning T...
#
#                                       review_content  \
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...
#
#                                          textoLimpio  \
# 0  a fantasy adventure that fuses greek mythology...
# 1  uma thurman as medusa the gorgon with a coiffu...
# ...

# %% [markdown]
# ### Lemmatizacion

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Descargar los recursos necesarios de NLTK
nltk.download('wordnet')

# Inicializar el lemmatizer de NLTK
#lemmatizer = WordNetLemmatizer()

# Función para lematizar el texto
def lematizarTexto(lista_palabras):
    lemmatizer = WordNetLemmatizer()
    palabrasLematizadas = [lemmatizer.lemmatize(palabra) for palabra in lista_palabras]  # Lematiza cada palabra
    return ' '.join(palabrasLematizadas)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dicam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Aplicar la lematización a la columna de texto
df_corpus['textoLematizado'] = df_corpus['textoSinStopWordsTokenizado'].apply(lematizarTexto)

# %% [markdown]
# # Construccion del Sistema

# %% [markdown]
# ### Vectorización utilizando tf-idf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Vectorización utilizando TF-IDF
vectorizer = TfidfVectorizer()
# Aplicar la vectorización sobre el corpus con el texto preprocesado
X_corpus = vectorizer.fit_transform(df_corpus['textoLematizado'])

# %% [markdown]
# ### Vectorizacion de la Query

# %%
# Vectorizar la query ene el mismo espacio vectorial del corpus
query1 = "Movies about space travel"
X_query1 = vectorizer.transform([query1])

# %%
# Vectorizar la query ene el mismo espacio vectorial del corpus
query2 = "Movies to watch with the family"
X_query2 = vectorizer.transform([query2])

# %% [markdown]
# ### Calculo de la similitud entre la query y el corpus

# %%
import numpy as np

# Calcular la similitud de coseno entre la query y el corpus
cosineSimilarityQuery1 = cosine_similarity(X_query1, X_corpus)

# Ordenar las similitudes de mayor a menor y obtener los índices de los 10 documentos más similares
topQuery1 = np.argsort(cosineSimilarityQuery1[0])[::-1][:10]

# %%
# Calcular la similitud de coseno entre la query y el corpus
cosineSimilarityQuery2 = cosine_similarity(X_query2, X_corpus)

# Ordenar las similitudes de mayor a menor y obtener los índices de los 10 documentos más similares
topQuery2 = np.argsort(cosineSimilarityQuery2[0])[::-1][:10]

# %% [markdown]
# ### Presentación de los resultados del sistema

# %%
print(f"Query 1: {query1} \n")
i = 1 
#En este bucle recorremos los 10 documentos y recuperamos la informacion de dichos indices
for idx in topQuery1 :
    similitud = cosineSimilarityQuery1[0][idx]  # Grado de similitud para el documento
    print(f"Top {i}")
    print(f"Documento {idx}:")
    print(f"  Grado de similitud: {similitud:.4f}")
    print(f"  Título: {df_corpus['movie_title'].iloc[idx]}")
    print(f"  Reseña: {df_corpus['review_content'].iloc[idx]}")
    print("\n")
    i = i+1
# Out:
# Query 1: Movies about space travel
#
# Top 1
# Documento 99226:
#   Grado de similitud: 0.6932
#   Título: Ad Astra
#   Reseña: Ad Astra isn't so much about the science of space and space travel as it is about the spaces between people.
#
#
# Top 2
# Documento 322525:
#   Grado de similitud: 0.6896
#   Título: First Man
#   Reseña: The special effects depicting space travel in this movie are loud, violent and claustrophobic, making the dangers of space travel seem more personal.
#
#
# Top 3
# Documento 128991:
#   Grado de similitud: 0.5850
#   Título: Apollo 11
#   Reseña: The film helps audiences travel into space with such ease. [Full Review in Spanish]
#
#
# Top 4
# Documento 204943:
#   Grado de similitud: 0.5552
#   Título: Captain Abu Raed
#   Reseña: His journey makes for a complex film that goes beyond the obvious. It, too, travels. And it travels well.
#
#
# Top 5
# Documento 433974:
#   Grado de similitud: 0.5363
#   Título: It! The Terror From Beyond Space
# ...

# %%
print(f"Query 2: {query2} \n")
i = 1 
for idx in topQuery2:
    print(f"Top {i}")
    similitud = cosineSimilarityQuery2[0][idx]  # Grado de similitud para el documento
    print(f"Documento {idx}:")
    print(f"  Grado de similitud: {similitud:.4f}")
    print(f"  Título: {df_corpus['movie_title'].iloc[idx]}")
    print(f"  Reseña: {df_corpus['review_content'].iloc[idx]}")
    print("\n")
    i = i+1
# Out:
# Query 2: Movies to watch with the family
#
# Top 1
# Documento 685035:
#   Grado de similitud: 0.7560
#   Título: Rock Dog
#   Reseña: A decent watch for families.
#
#
# Top 2
# Documento 685036:
#   Grado de similitud: 0.7560
#   Título: Rock Dog
#   Reseña: A decent watch for families.
#
#
# Top 3
# Documento 212162:
#   Grado de similitud: 0.7194
#   Título: Cats
#   Reseña: What did I just watch?
#
#
# Top 4
# Documento 153630:
#   Grado de similitud: 0.7194
#   Título: Beasts of the Southern Wild
#   Reseña: When can we watch it again?
#
#
# Top 5
# Documento 1041410:
#   Grado de similitud: 0.7194
#   Título: Why Him?
#   Reseña: Why watch "Why Him?"
#
#
# Top 6
# Documento 462317:
#   Grado de similitud: 0.6946
#   Título: Kiss the Bride
#   Reseña: It's about family.
#
#
# Top 7
# Documento 966492:
#   Grado de similitud: 0.6451
#   Título: The Watch
#   Reseña: The Watch is hard to watch.
#
#
# Top 8
# Documento 681005:
#   Grado de similitud: 0.6446
# ...

# %% [markdown]
# ### Analisis de Resultados

# %% [markdown]
# Limitamos el listado de peliculas a 10 para observar cuales son las mas relevantes y por los resultados el sistema devulve parcialmente resutados correctos.
#
# Query 1: Movies about space travel
# El documemto en el ranking 4 y 10 no son los resultados que esperabamos ya que la consulta era sobre viajes en el tiempo pero dado que no se trato como un bigrama la palabra space travel, el sistema busco de forma independiente las palabras dado resultados no relevantes.
#
# Query 2: Movies to watch with the family
# El documemto en el ranking 3, 4 y 5 la palabra watch tiene el mismo peso que la palabra family y nos esta devolviendo resultados no relevantes.
#
# Una mejora seria incorporar el uso de n-gramas en la vectorizacion y dado que el corpus es mucho mas grande y con información variada se tendria que tomar en cuenta modificar los parametros de la tecnica de vectorizacion TF-IDF
